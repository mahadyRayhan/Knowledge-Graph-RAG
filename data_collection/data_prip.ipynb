# %%
import os
import json
import pandas as pd
import re
from collections import defaultdict
from typing import List
from dotenv import load_dotenv
from IPython.display import display

# %%
load_dotenv()
S2_API_KEY = os.getenv("SEMANTIC_SCHOLAR_API_KEY")

# %%
NSF_RAW_DATA_DIR = "../data/ranking_data/" 
if not os.path.exists(NSF_RAW_DATA_DIR):
    print(f"Error: Ranking data directory not found at {NSF_RAW_DATA_DIR}")

# %%
def safe_get(dictionary, keys):
    """Safely gets nested dictionary values."""
    for key in keys:
        if isinstance(dictionary, dict):
            dictionary = dictionary.get(key)
        else:
            return None
    return dictionary

def extract_keywords(text: str, top_n: int = 15) -> List[str]:
    """A simple keyword extractor based on word frequency (ignoring common stop words)."""
    if not isinstance(text, str):
        return []
    stop_words = {'the', 'a', 'an', 'and', 'in', 'is', 'of', 'for', 'to', 'with', 'on', 'this', 'grant', 'project', 'research', 'award', 'support', 'program'}
    words = re.findall(r'\b\w{4,}\b', text.lower()) # Find words with 4+ letters
    filtered_words = [word for word in words if word not in stop_words]
    word_counts = defaultdict(int)
    for word in filtered_words:
        word_counts[word] += 1
    return sorted(word_counts, key=word_counts.get, reverse=True)[:top_n]

# %%
def create_profiles_from_raw_data() -> pd.DataFrame:
    """
    Reads all raw NSF JSONs, aggregates ALL data for each unique researcher,
    and returns a DataFrame of rich profiles.
    """
    print(f"--- Step 1: Loading and Processing NSF Data from '{NSF_RAW_DATA_DIR}' ---")
    
    records = []
    for sub_dir in os.listdir(NSF_RAW_DATA_DIR):
        # sub_dir = '2024'
        sub_directory = os.path.join(NSF_RAW_DATA_DIR, sub_dir)
        if os.path.isdir(sub_directory):
            print(f"Reading files in {sub_dir}...")
            for filename in os.listdir(sub_directory):
                if filename.endswith('.json'):
                    filepath = os.path.join(sub_directory, filename)
                    try:
                        with open(filepath, 'r') as file:
                            data = json.load(file)
                        
                        # --- THE FIX IS HERE ---
                        # 1. Get the 'pi' list from the JSON data.
                        pi_list = data.get("pi")
                        
                        # 2. Add a safety check. If 'pi' is missing, is null, or is not a list, skip this file.
                        if not isinstance(pi_list, list):
                            print(f"Warning: 'pi' key in {filepath} is missing or not a list. Skipping.")
                            continue

                        # If we get here, we know pi_list is safe to iterate over.
                        award_type = data.get("awd_istr_txt")
                        award_title = data.get("awd_titl_txt")
                        abstract = data.get("abst_narr_txt")
                        org_name = data.get("org_long_name")
                        org_name2 = data.get("org_long_name2")
                        perf_inst_name = safe_get(data, ["perf_inst", "perf_inst_name"])

                        pgm_ele_list = data.get("pgm_ele")
                        program_element = pgm_ele_list[0].get("pgm_ele_long_name") if isinstance(pgm_ele_list, list) and len(pgm_ele_list) > 0 else None

                        pgm_ref_list = data.get("pgm_ref")
                        program_reference = pgm_ref_list[0].get("pgm_ref_long_name") if isinstance(pgm_ref_list, list) and len(pgm_ref_list) > 0 else None
                        
                        for pi in pi_list:
                            records.append({
                                "pi_id": pi.get("nsf_id"),
                                "pi_full_name": pi.get("pi_full_name", "").strip(),
                                "email": pi.get("pi_email_addr"),
                                "role": pi.get("proj_role_code2", "").strip() if pi.get("proj_role_code2") else None,
                                "award_title": award_title, "award_type": award_type,
                                "abstract": abstract, "perf_inst_name": perf_inst_name,
                                "org_name": org_name, "org_name2": org_name2,
                                "program_element": program_element, "program_reference": program_reference,
                            })
                    except Exception as e:
                        print(f"Error reading or processing {filepath}: {e}")
        break
    if not records:
        print("No records were processed. Returning empty DataFrame.")
        return pd.DataFrame()
        
    df = pd.DataFrame(records)
    df.dropna(subset=['pi_id', 'pi_full_name'], inplace=True)

    print(f"\nAggregating data for {df['pi_id'].nunique()} unique researchers...")
    
    text_fields = ['award_title', 'abstract', 'program_element', 'program_reference']
    df['content'] = df[text_fields].fillna('').astype(str).agg(' '.join, axis=1)

    agg_funcs = {
        'pi_full_name': (lambda x: x.mode()[0]), 'email': (lambda x: list(x.dropna().unique())),
        'role': (lambda x: list(x.unique())), 'award_title': list, 'award_type': list,
        'perf_inst_name': (lambda x: list(x.dropna().unique())),
        'org_name': (lambda x: list(x.dropna().unique())),
        'program_element': (lambda x: list(x.dropna().unique())),
        'program_reference': (lambda x: list(x.dropna().unique())), 'content': ' '.join
    }
    profiles_df = df.groupby('pi_id').agg(agg_funcs).reset_index()

    profiles_df['primary_affiliation'] = profiles_df['perf_inst_name'].apply(lambda x: x[0] if x else None)
    profiles_df['keywords'] = profiles_df['content'].apply(extract_keywords)
    
    print("--- Step 1 Complete: NSF Profiles Created ---")
    return profiles_df

# %%
# ranking_data = create_profiles_from_raw_data()
# ranking_data.head()

# %%
OUTPUT_DIR = "s2_author_data"
from scholar_api_service import SemanticScholarAPI

def run_enrichment_pipeline():
    """ The main orchestrator function. """
    profiles_df = create_profiles_from_raw_data()
    
    if profiles_df.empty:
        print("No profiles to process. Exiting.")
        return

    print("\n--- Step 2: Starting Bulk Data Fetching from Semantic Scholar ---")
    
    if not S2_API_KEY:
        print("FATAL: SEMANTIC_SCHOLAR_API_KEY not found. Exiting.")
        return
        
    s2_api = SemanticScholarAPI(api_key=S2_API_KEY)
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    print(f"Output will be saved to '{OUTPUT_DIR}'.")
    
    profiles_df = profiles_df.iloc[:50,:]
    total_researchers = len(profiles_df)
    print(f"Found {total_researchers} unique researcher profiles to process.")
    
    for i, profile in profiles_df.iterrows():
        pi_id = profile['pi_id']
        name = profile['pi_full_name']
        
        print(f"\n[{i+1}/{total_researchers}] Processing: {name} (NSF ID: {pi_id})")

        output_filename = os.path.join(OUTPUT_DIR, f"{pi_id}.json")
        if os.path.exists(output_filename):
            print(f"  -> Data already exists. Skipping.")
            continue

        # --- KEY CHANGE FOR EFFICIENCY ---
        # Call the new efficient search method
        candidates = s2_api.search_authors_with_content(name)
        if not candidates:
            print("  -> No candidates found on Semantic Scholar.")
            continue
            
        best_match = s2_api.find_best_author_match(candidates, profile)
        if not best_match:
            print("  -> Could not determine a confident match.")
            continue
            
        s2_id = best_match['authorId']
        
        print(f"  -> Fetching full details for S2 ID: {s2_id}...")
        author_details = s2_api.get_author_details(s2_id)
        
        if author_details:
            author_details['nsf_pi_id'] = pi_id
            with open(output_filename, 'w') as f:
                json.dump(author_details, f, indent=4)
            print(f"  -> SUCCESS: Saved detailed data to {output_filename}")
        else:
            print(f"  -> FAILED: Could not fetch details for S2 ID {s2_id}.")

    print("\n--- Full Enrichment Pipeline Complete ---")

if __name__ == "__main__":
    run_enrichment_pipeline()
# Out:
# --- Step 1: Loading and Processing NSF Data from '../data/ranking_data/' ---
# Reading files in 2013...
# Warning: 'pi' key in ../data/ranking_data/2013/1323822.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1324294.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323652.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323649.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323429.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323104.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323820.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323991.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1322928.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323728.json is missing or not a list. Skipping.
# Warning: 'pi' key in ../data/ranking_data/2013/1323837.json is missing or not a list. Skipping.
#
# Aggregating data for 17454 unique researchers...
# --- Step 1 Complete: NSF Profiles Created ---
#
# --- Step 2: Starting Bulk Data Fetching from Semantic Scholar ---
# Semantic Scholar API client initialized with API key.
# Output will be saved to 's2_author_data'.
# Found 50 unique researcher profiles to process.
#
# [1/50] Processing: Axel K Schmitt (NSF ID: 000002157)
#   -> Data already exists. Skipping.
#
# [2/50] Processing: Huan Z Huang (NSF ID: 000003534)
#   -> Data already exists. Skipping.
#
# [3/50] Processing: Maryann P Feldman (NSF ID: 000004317)
#   -> Data already exists. Skipping.
#
# [4/50] Processing: Ioan Bejenaru (NSF ID: 000004907)
#   -> Data already exists. Skipping.
#
# [5/50] Processing: Qing Zhou (NSF ID: 000005427)
#   -> Data already exists. Skipping.
#
# [6/50] Processing: edgar a mendoza (NSF ID: 000010704)
#   -> Data already exists. Skipping.
#
# [7/50] Processing: Martha H Conklin (NSF ID: 000013206)
#   -> Data already exists. Skipping.
#
# [8/50] Processing: Catherine A Pilachowski (NSF ID: 000017330)
#   -> Data already exists. Skipping.
#
# [9/50] Processing: Leonard S Sklar (NSF ID: 000018520)
#   -> Data already exists. Skipping.
#
# [10/50] Processing: Ryan P O'Hayre (NSF ID: 000023979)
#   -> Data already exists. Skipping.
#
# [11/50] Processing: Louis DiMauro (NSF ID: 000028687)
#   -> Matching against NSF Keywords: {'laser', 'intense', 'scaled', 'physics', 'interactions', 'atom'}
#     - Candidate 'L.R. DiMauro' | Topical Score = 10
#     - Candidate 'Louis F. DiMauro' | Topical Score = 20
#     - Candidate 'L. DiMauro' | Topical Score = 10
#     - Candidate 'L. DiMauro' | Topical Score = 60
#     - Candidate 'Louis F DiMauro' | Topical Score = 30
#   -> Best Match Selected: 'L. DiMauro' with a score of 89.00
#   -> Fetching full details for S2 ID: 6570949...
#   -> SUCCESS: Saved detailed data to s2_author_data/000028687.json
#
# [12/50] Processing: Alison L Coil (NSF ID: 000028828)
#   -> Matching against NSF Keywords: {'collaborative', 'field', 'survey', 'evolution', 'mosfire', 'deep'}
#     - Candidate 'A. Coil' | Topical Score = 50
#   -> Best Match Selected: 'A. Coil' with a score of 84.90
#   -> Fetching full details for S2 ID: 6957815...
#   -> SUCCESS: Saved detailed data to s2_author_data/000028828.json
#
# [13/50] Processing: Alicia M Koontz (NSF ID: 000030425)
#   -> Matching against NSF Keywords: {'student', 'site', 'american', 'engineering', 'rehabilitation', 'placements'}
#     - Candidate 'A. Koontz' | Topical Score = 60
#     - Candidate 'M. Alicia' | Topical Score = 0
#     - Candidate 'Alicia Koontz' | Topical Score = 30
#     - Candidate 'P. R. Alicia M. Koontz' | Topical Score = 0
#     - Candidate 'Alicia M Koontz' | Topical Score = 0
#   -> Best Match Selected: 'A. Koontz' with a score of 84.50
#   -> Fetching full details for S2 ID: 47670784...
#   -> SUCCESS: Saved detailed data to s2_author_data/000030425.json
#
# [14/50] Processing: Alexander G Agrios (NSF ID: 000031542)
#   -> Matching against NSF Keywords: {'interfaces', 'eager', 'novel', 'cells', 'solar', 'nanostructured'}
#     - Candidate 'Alexander G. Agrios' | Topical Score = 30
#     - Candidate 'Alexander G. Agrios' | Topical Score = 0
#   -> Best Match Selected: 'Alexander G. Agrios' with a score of 33.90
#   -> Fetching full details for S2 ID: 8650380...
#   -> SUCCESS: Saved detailed data to s2_author_data/000031542.json
#
# [15/50] Processing: James E Aguirre (NSF ID: 000032983)
#   -> Matching against NSF Keywords: {'effect', 'dovich', 'observations', 'resolution', 'high', 'galaxies', 'clusters', 'sunyaev', 'using'}
#     - Candidate 'J. Aguirre' | Topical Score = 50
#     - Candidate 'J. Aguirre' | Topical Score = 50
#     - Candidate 'J. Aguirre' | Topical Score = 90
#     - Candidate 'J. E. Aguirre' | Topical Score = 40
#     - Candidate 'James E. Aguirre' | Topical Score = 0
#   -> Best Match Selected: 'J. Aguirre' with a score of 110.50
#   -> Fetching full details for S2 ID: 4703302...
#   -> SUCCESS: Saved detailed data to s2_author_data/000032983.json
#
# [16/50] Processing: Silas D Alben (NSF ID: 000033171)
#   -> Matching against NSF Keywords: {'models', 'methods', 'numerical', 'fins', 'membranes', 'collaborative', 'wings', 'flexible'}
#     - Candidate 'S. Alben' | Topical Score = 60
#   -> Best Match Selected: 'S. Alben' with a score of 70.90
#   -> Fetching full details for S2 ID: 1889794...
#   -> SUCCESS: Saved detailed data to s2_author_data/000033171.json
#
# [17/50] Processing: Nancy Jones (NSF ID: 000036365)
#   -> Matching against NSF Keywords: {'cyberwatch', 'west'}
#     - Candidate 'N. Jones' | Topical Score = 0
#     - Candidate 'N. Jones' | Topical Score = 0
#     - Candidate 'Nancy E. Jones' | Topical Score = 0
#     - Candidate 'N. Jones' | Topical Score = 0
#     - Candidate 'N. L. Jones' | Topical Score = 0
#   -> Best Match Selected: 'N. Jones' with a score of 8.60
#   -> Fetching full details for S2 ID: 153468495...
#   -> SUCCESS: Saved detailed data to s2_author_data/000036365.json
#
# [18/50] Processing: Jonathan Z Sun (NSF ID: 000038609)
#   -> Matching against NSF Keywords: {'goali', 'magnetic', 'transfer', 'spin', 'nanostructures'}
#     - Candidate 'Jonathan Z. Sun' | Topical Score = 30
#     - Candidate 'Z. Jonathan' | Topical Score = 0
#     - Candidate 'Jonathan Z. Sun' | Topical Score = 30
#     - Candidate 'Z. S. Jonathan' | Topical Score = 0
#     - Candidate 'Jonathan Z. Sun' | Topical Score = 20
#   -> Best Match Selected: 'Jonathan Z. Sun' with a score of 42.80
#   -> Fetching full details for S2 ID: 1700620...
#   -> SUCCESS: Saved detailed data to s2_author_data/000038609.json
#
# [19/50] Processing: An-I Wang (NSF ID: 000039400)
#   -> Matching against NSF Keywords: {'science', 'computer', 'participation', 'broadening'}
#     - Candidate 'I-an Wang' | Topical Score = 0
#     - Candidate 'Andy Wang' | Topical Score = 0
#     - Candidate 'An-I Wang' | Topical Score = 0
#     - Candidate 'Annie Wang' | Topical Score = 0
#     - Candidate 'An-I Wang' | Topical Score = 30
#   -> Best Match Selected: 'An-I Wang' with a score of 33.70
#   -> Fetching full details for S2 ID: 2296649...
#   -> SUCCESS: Saved detailed data to s2_author_data/000039400.json
#
# [20/50] Processing: Barbara Hillery (NSF ID: 000039761)
#   -> Matching against NSF Keywords: {'technology', 'policy', 'novel', 'energy', 'campus', 'collaborative', 'minor', 'learning', 'disciplinary', 'undergraduate', 'multi', 'enhance', 'science', 'stem'}
#     - Candidate 'B. Hillery' | Topical Score = 10
#     - Candidate 'B. Hillery' | Topical Score = 30
#     - Candidate 'Barbara Hillery' | Topical Score = 100
#     - Candidate 'Barbara R. Hillery' | Topical Score = 0
#   -> Best Match Selected: 'Barbara Hillery' with a score of 100.20
#   -> Fetching full details for S2 ID: 2080252865...
#   -> SUCCESS: Saved detailed data to s2_author_data/000039761.json
#
# [21/50] Processing: Satyanarayana Swamy-Mruthinti (NSF ID: 000041036)
#   -> Matching against NSF Keywords: {'planning', 'teaching', 'reforms', 'wiser', 'setting', 'stage', 'based', 'evidence', 'implementation', 'wider', 'commitment', 'educational', 'practices', 'institutional', 'stem'}
#     - Candidate 'S. S. Mruthinti' | Topical Score = 0
#     - Candidate 'S. Swamy-Mruthinti' | Topical Score = 30
#     - Candidate 'Satyanarayana Swamy Mruthinti' | Topical Score = 0
#   -> Best Match Selected: 'S. Swamy-Mruthinti' with a score of 32.20
#   -> Fetching full details for S2 ID: 1401365264...
#   -> SUCCESS: Saved detailed data to s2_author_data/000041036.json
#
# [22/50] Processing: Philip J Weilerstein (NSF ID: 000041172)
#   -> Matching against NSF Keywords: {'corps', 'curriculum', 'network', 'market', 'mrsec', 'scientific', 'national', 'evaluating', 'lens', 'implementing', 'coordinating', 'connecting', 'training', 'innovation', 'developing'}
#     - Candidate 'P. Weilerstein' | Topical Score = 60
#   -> Best Match Selected: 'P. Weilerstein' with a score of 62.50
#   -> Fetching full details for S2 ID: 30918119...
#   -> SUCCESS: Saved detailed data to s2_author_data/000041172.json
#
# [23/50] Processing: Yevgeniya V Zastavker (NSF ID: 000045678)
#   -> Matching against NSF Keywords: {'supporting', 'student', 'collaborative', 'understanding', 'intrinsic', 'motivation', 'courses', 'stem'}
#     - Candidate 'Y. Zastavker' | Topical Score = 80
#   -> Best Match Selected: 'Y. Zastavker' with a score of 88.70
#   -> Fetching full details for S2 ID: 2261404...
#   -> SUCCESS: Saved detailed data to s2_author_data/000045678.json
#
# [24/50] Processing: Guijun Wang (NSF ID: 000054537)
#   -> Matching against NSF Keywords: {'assembly', 'synthesis', 'glycomimetics', 'self'}
#     - Candidate 'Wang Guijun' | Topical Score = 0
#     - Candidate 'Wan Guijun' | Topical Score = 0
#     - Candidate 'Gui-sheng Wang' | Topical Score = 0
#     - Candidate 'Gui-Jun Wang' | Topical Score = 0
#     - Candidate 'Guijun Wang' | Topical Score = 0
#   -> Best Match Selected: 'Wang Guijun' with a score of 4.80
#   -> Fetching full details for S2 ID: 152571256...
#   -> SUCCESS: Saved detailed data to s2_author_data/000054537.json
#
# [25/50] Processing: John Oakey (NSF ID: 000055688)
#   -> Matching against NSF Keywords: {'screening', 'microfluidic', 'encapsulation', 'rationally', 'biomaterials', 'designed', 'high', 'career', 'cell', 'throughput'}
#     - Candidate 'J. Oakey' | Topical Score = 10
#     - Candidate 'J. Oakey' | Topical Score = 70
#     - Candidate 'J. Oakey' | Topical Score = 30
#     - Candidate 'O. John' | Topical Score = 0
#     - Candidate 'John Oakey' | Topical Score = 20
#   -> Best Match Selected: 'J. Oakey' with a score of 78.20
#   -> Fetching full details for S2 ID: 144012488...
#   -> SUCCESS: Saved detailed data to s2_author_data/000055688.json
#
# [26/50] Processing: James K Ferri (NSF ID: 000055944)
#   -> Matching against NSF Keywords: {'screencasts', 'collaborative', 'education', 'chemical', 'enhancing', 'engineering'}
#     - Candidate 'J. Ferri' | Topical Score = 50
#     - Candidate 'J. K. Ferri' | Topical Score = 20
#     - Candidate 'James K. Ferri' | Topical Score = 0
#   -> Best Match Selected: 'J. Ferri' with a score of 57.30
#   -> Fetching full details for S2 ID: 31787279...
#   -> SUCCESS: Saved detailed data to s2_author_data/000055944.json
#
# [27/50] Processing: Vanessa L Fong (NSF ID: 000056027)
#   -> Matching against NSF Keywords: {'childrearing', 'international', 'through', 'teaching', 'fertility', 'methods', 'comparative', 'perspectives', 'study', 'china', 'mixed', 'childbearing', 'career', 'limitation', 'under'}
#     - Candidate 'Vanessa L. Fong' | Topical Score = 110
#     - Candidate 'Vanessa L. Fong' | Topical Score = 0
#     - Candidate 'Vanessa L. Fong' | Topical Score = 50
#   -> Best Match Selected: 'Vanessa L. Fong' with a score of 117.00
#   -> Fetching full details for S2 ID: 6432032...
#   -> SUCCESS: Saved detailed data to s2_author_data/000056027.json
#
# [28/50] Processing: Marcus A Alfred (NSF ID: 000056320)
#   -> Matching against NSF Keywords: {'through', 'repurposing', 'students', 'astronomy', 'learning', 'media', 'popular', 'cosmology', 'physics', 'engaging', 'involved'}
#     - Candidate 'A. Marcus' | Topical Score = 0
#     - Candidate 'A. Marcus' | Topical Score = 30
#     - Candidate 'A. Marcus' | Topical Score = 20
#     - Candidate 'A. Alfred' | Topical Score = 0
#     - Candidate 'A. Alfred' | Topical Score = 0
#   -> Best Match Selected: 'A. Marcus' with a score of 48.20
#   -> Fetching full details for S2 ID: 36106620...
#   -> SUCCESS: Saved detailed data to s2_author_data/000056320.json
#
# [29/50] Processing: Paul P Maglio (NSF ID: 000056763)
#   -> Matching against NSF Keywords: {'service', 'workshop', 'develop', 'agenda', 'innovation'}
#     - Candidate 'P. Maglio' | Topical Score = 40
#     - Candidate 'P. Paul' | Topical Score = 0
#     - Candidate 'P. Paul' | Topical Score = 0
#     - Candidate 'P. Paul' | Topical Score = 0
#     - Candidate 'Paul P. Maglio' | Topical Score = 10
#   -> Best Match Selected: 'P. Maglio' with a score of 59.20
#   -> Fetching full details for S2 ID: 144452579...
#   -> SUCCESS: Saved detailed data to s2_author_data/000056763.json
#
# [30/50] Processing: Ryan G Benton (NSF ID: 000057761)
#   -> Matching against NSF Keywords: {'prediction', 'analysis', 'collaborative', 'ucrc', 'based', 'fundamental', 'link', 'visualization'}
#     - Candidate 'Ryan G. Benton' | Topical Score = 50
#     - Candidate 'Ryan Benton' | Topical Score = 50
#     - Candidate 'Ryan Benton' | Topical Score = 30
#     - Candidate 'Ryan G Benton' | Topical Score = 10
#     - Candidate 'Ryan G. Benton' | Topical Score = 0
#   -> Best Match Selected: 'Ryan G. Benton' with a score of 56.70
#   -> Fetching full details for S2 ID: 145082377...
#   -> SUCCESS: Saved detailed data to s2_author_data/000057761.json
#
# [31/50] Processing: David M Letscher (NSF ID: 000057949)
#   -> No candidates found on Semantic Scholar.
#
# [32/50] Processing: Shlomo Dubnov (NSF ID: 000058512)
#   -> Matching against NSF Keywords: {'computing', 'planning', 'ucrc', 'semantic'}
#     - Candidate 'S. Dubnov' | Topical Score = 30
#     - Candidate 'Shlomo Dubnov Crca' | Topical Score = 0
#     - Candidate 'Shlomo Dubnov Uscd' | Topical Score = 0
#     - Candidate 'Dubnov Shlomo' | Topical Score = 0
#     - Candidate 'Measures Shlomo Dubnov' | Topical Score = 0
#   -> Best Match Selected: 'S. Dubnov' with a score of 48.80
#   -> Fetching full details for S2 ID: 2204186...
#   -> SUCCESS: Saved detailed data to s2_author_data/000058512.json
#
# [33/50] Processing: Ramesh Johari (NSF ID: 000058591)
#   -> Matching against NSF Keywords: {'extreme', 'collaborative', 'networks', 'densification', 'wireless'}
#     - Candidate 'Ramesh Johari' | Topical Score = 30
#     - Candidate 'Ramesh Johari' | Affiliation match! (+100 points)
#     - Candidate 'Ramesh Johari' | Topical Score = 0
#     - Candidate 'Ramesh Johari' | Topical Score = 0
#     - Candidate 'Ramesh Johari' | Topical Score = 10
#     - Candidate 'R. May' | Topical Score = 0
#   -> Best Match Selected: 'Ramesh Johari' with a score of 146.70
#   -> Fetching full details for S2 ID: 1790944...
#   -> SUCCESS: Saved detailed data to s2_author_data/000058591.json
#
# [34/50] Processing: Christopher V Davis (NSF ID: 000058760)
#   -> Matching against NSF Keywords: {'economic', 'capacity', 'maine', 'building', 'diversify', 'mariculture', 'downeast', 'opportunities', 'innovation', 'shellfish'}
#     - Candidate 'C. V. Davis' | Topical Score = 0
#     - Candidate 'C. Davis' | Topical Score = 0
#     - Candidate 'C. Davis' | Topical Score = 20
#     - Candidate 'C. Davis' | Topical Score = 0
#     - Candidate 'Christopher V. Davis' | Topical Score = 0
#   -> Best Match Selected: 'C. Davis' with a score of 21.20
#   -> Fetching full details for S2 ID: 2389015...
#   -> SUCCESS: Saved detailed data to s2_author_data/000058760.json
#
# [35/50] Processing: Stephen Low (NSF ID: 000058851)
#   -> Matching against NSF Keywords: {'secrets', 'universe', 'full', 'scale', 'development'}
#     - Candidate 'S. G. Low' | Topical Score = 10
#     - Candidate 'Stephen Low' | Topical Score = 10
#     - Candidate 'Stephen Low' | Topical Score = 0
#     - Candidate 'Stephen Low' | Topical Score = 10
#     - Candidate 'W. K. Low' | Topical Score = 0
#   -> Best Match Selected: 'S. G. Low' with a score of 13.00
#   -> Fetching full details for S2 ID: 48685445...
# HTTP error occurred: 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/author/48685445?fields=name%2Caffiliations%2CpaperCount%2CcitationCount%2ChIndex%2Cpapers.title%2Cpapers.year%2Cpapers.venue%2Cpapers.citationCount%2Cpapers.authors%2Cpapers.abstract
# Server Response Content: {"message": "Too Many Requests. Please wait and try again or apply for a key for higher rate limits. https://www.semanticscholar.org/product/api#api-key-form", "code": "429"}
#   -> FAILED: Could not fetch details for S2 ID 48685445.
#
# [36/50] Processing: Oliver Fiehn (NSF ID: 000058886)
#   -> Matching against NSF Keywords: {'international', 'network', 'plant', 'metabolomics', 'algae', 'integrating', 'microbial', 'national', 'coordinating', 'coordination'}
#     - Candidate 'O. Fiehn' | Topical Score = 30
#     - Candidate 'O. Fiehn' | Topical Score = 100
#     - Candidate 'O. Fiehn' | Topical Score = 50
#     - Candidate 'O. Fiehn' | Topical Score = 20
#     - Candidate 'Oliver Fiehn' | Topical Score = 40
#   -> Best Match Selected: 'O. Fiehn' with a score of 167.50
#   -> Fetching full details for S2 ID: 1763019...
#   -> SUCCESS: Saved detailed data to s2_author_data/000058886.json
#
# [37/50] Processing: William C Hammond (NSF ID: 000058892)
#   -> Matching against NSF Keywords: {'contemporary', 'uplift', 'basin', 'nature', 'sierra', 'collapse', 'nevada', 'great', 'revealing', 'system'}
#     - Candidate 'W. Hammond' | Topical Score = 80
#     - Candidate 'W. Hammond' | Topical Score = 0
#     - Candidate 'W. C. Hammond' | Topical Score = 30
#     - Candidate 'William C Hammond' | Topical Score = 0
#     - Candidate 'William C. Hammond' | Topical Score = 0
#   -> Best Match Selected: 'W. Hammond' with a score of 91.50
#   -> Fetching full details for S2 ID: 20644780...
#   -> SUCCESS: Saved detailed data to s2_author_data/000058892.json
#
# [38/50] Processing: Yihua B Yu (NSF ID: 000059487)
#   -> Matching against NSF Keywords: {'fluorinated', 'complexes', 'paramagnetic', 'multichromic', 'engineering'}
#     - Candidate 'Y. Yu' | Topical Score = 10
#     - Candidate 'Y. Yu' | Topical Score = 30
#   -> Best Match Selected: 'Y. Yu' with a score of 43.60
#   -> Fetching full details for S2 ID: 35660492...
#   -> SUCCESS: Saved detailed data to s2_author_data/000059487.json
#
# [39/50] Processing: Edwin H Brown (NSF ID: 000059501)
#   -> Matching against NSF Keywords: {'laurentian', 'components', 'collaborative', 'washington', 'baltican', 'terranes'}
#     - Candidate 'E. Brown' | Topical Score = 50
#     - Candidate 'E. H. Brown' | Topical Score = 0
#     - Candidate 'Edwin H. Brown' | Topical Score = 10
#     - Candidate 'E. L. Brown' | Topical Score = 0
#     - Candidate 'H. E. Brown' | Topical Score = 0
#   -> Best Match Selected: 'E. Brown' with a score of 58.10
#   -> Fetching full details for S2 ID: 82288370...
#   -> SUCCESS: Saved detailed data to s2_author_data/000059501.json
#
# [40/50] Processing: Urmila M Diwekar (NSF ID: 000059541)
#   -> Matching against NSF Keywords: {'2014', 'trans', 'workshop', 'june', 'sustainability', 'tardis', 'development', 'atlantic', 'interchange'}
#     - Candidate 'U. Diwekar' | Topical Score = 70
#   -> Best Match Selected: 'U. Diwekar' with a score of 97.80
#   -> Fetching full details for S2 ID: 3290498...
#   -> SUCCESS: Saved detailed data to s2_author_data/000059541.json
#
# [41/50] Processing: Octaviana Trujillo (NSF ID: 000059557)
#   -> Matching against NSF Keywords: {'curriculum', 'native', 'southwest', 'integrated', 'lands'}
#     - Candidate 'Octaviana V. Trujillo' | Topical Score = 20
#   -> Best Match Selected: 'Octaviana V. Trujillo' with a score of 21.10
#   -> Fetching full details for S2 ID: 115825646...
#   -> SUCCESS: Saved detailed data to s2_author_data/000059557.json
#
# [42/50] Processing: Martin Wainwright (NSF ID: 000060031)
#   -> Matching against NSF Keywords: {'approaches', 'collaborative', 'high', 'dimensions', 'robustness', 'medium'}
#     - Candidate 'M. Wainwright' | Topical Score = 10
#     - Candidate 'M. Wainwright' | Topical Score = 40
#     - Candidate 'Martin J. Wainwright' | Topical Score = 20
#     - Candidate 'Martin J. Wainwright' | Topical Score = 0
#     - Candidate 'A. Wainwright' | Topical Score = 0
#   -> Best Match Selected: 'M. Wainwright' with a score of 73.60
#   -> Fetching full details for S2 ID: 1721860...
#   -> SUCCESS: Saved detailed data to s2_author_data/000060031.json
#
# [43/50] Processing: Teresa E Pawlowska (NSF ID: 000060079)
#   -> Matching against NSF Keywords: {'site', 'foes', 'towards', 'synthesis', 'microbial', 'friends', 'interspecific', 'interactions'}
#     - Candidate 'T. Pawlowska' | Topical Score = 40
#     - Candidate 'Teresa E Pawlowska' | Topical Score = 0
#   -> Best Match Selected: 'T. Pawlowska' with a score of 45.20
#   -> Fetching full details for S2 ID: 4336808...
#   -> SUCCESS: Saved detailed data to s2_author_data/000060079.json
#
# [44/50] Processing: Stephen D Sebestyen (NSF ID: 000060239)
#   -> Matching against NSF Keywords: {'catchment', 'climatic', 'change', 'seminar', 'forest', 'japan', 'hydrology', 'responses', 'environmental', 'joint', 'biogeochemistry'}
#     - Candidate 'S. Sebestyen' | Topical Score = 60
#     - Candidate 'S. Sebestyen' | Topical Score = 110
#     - Candidate 'Stephen D. Sebestyen' | Topical Score = 0
#   -> Best Match Selected: 'S. Sebestyen' with a score of 125.90
#   -> Fetching full details for S2 ID: 6345279...
#   -> SUCCESS: Saved detailed data to s2_author_data/000060239.json
#
# [45/50] Processing: Jon B Hageman (NSF ID: 000060241)
#   -> Matching against NSF Keywords: {'completing', 'mesoamerican', 'moed', 'database', 'online', 'ethnobotanical'}
#     - Candidate 'J. Hageman' | Topical Score = 0
#   -> Best Match Selected: 'J. Hageman' with a score of 2.10
#   -> Fetching full details for S2 ID: 95092559...
#   -> SUCCESS: Saved detailed data to s2_author_data/000060241.json
#
# [46/50] Processing: Christopher B Smith (NSF ID: 000060332)
#   -> Matching against NSF Keywords: {'process', 'through', 'detection', 'goali', 'friction', 'enabling', 'defects', 'time', 'welding', 'based', 'stir', 'physics', 'dynamic', 'real', 'identification'}
#     - Candidate 'Christopher B. Smith' | Topical Score = 10
#     - Candidate 'Christopher B. Smith' | Topical Score = 80
#     - Candidate 'Christopher B R Smith' | Topical Score = 10
#     - Candidate 'C. B. Smith' | Topical Score = 0
#     - Candidate 'C. B. Smith' | Topical Score = 0
#   -> Best Match Selected: 'Christopher B. Smith' with a score of 83.10
#   -> Fetching full details for S2 ID: 2116354876...
#   -> SUCCESS: Saved detailed data to s2_author_data/000060332.json
#
# [47/50] Processing: Peter Andolfatto (NSF ID: 000060680)
#   -> Matching against NSF Keywords: {'physiological', 'collaborative', 'butterflies', 'color', 'genomics', 'vision'}
#     - Candidate 'P. Andolfatto' | Topical Score = 40
#     - Candidate 'Peter Andolfatto' | Topical Score = 10
#     - Candidate 'Peter Andolfatto' | Topical Score = 0
#     - Candidate 'Peter Andolfatto' | Topical Score = 0
#   -> Best Match Selected: 'P. Andolfatto' with a score of 50.70
#   -> Fetching full details for S2 ID: 123519236...
#   -> SUCCESS: Saved detailed data to s2_author_data/000060680.json
#
# [48/50] Processing: Qun Li (NSF ID: 000061001)
#   -> Matching against NSF Keywords: {'student', 'infocom', 'sensing', 'small', 'allocation', 'travel', 'spectrum', 'nets', '2013', 'radio', 'charging', 'networks', 'cognitive', 'ieee'}
#     - Candidate 'Q. Li' | Topical Score = 0
#     - Candidate 'Q. Li' | Topical Score = 0
#     - Candidate 'Liang Qun' | Topical Score = 0
#     - Candidate 'Q. Li' | Topical Score = 0
#   -> Best Match Selected: 'Q. Li' with a score of 3.40
#   -> Fetching full details for S2 ID: 2108647443...
#   -> SUCCESS: Saved detailed data to s2_author_data/000061001.json
#
# [49/50] Processing: Stefan F Preble (NSF ID: 000061012)
#   -> Matching against NSF Keywords: {'modulators', 'laser', 'ultracompact', 'optical', 'photonics', 'integrated', 'collaborative', 'acquisition', 'graphene', 'based', 'transceiver', 'high', 'metal', 'performance', 'inas'}
#     - Candidate 'S. Preble' | Topical Score = 110
#     - Candidate 'Stefan F. Preble' | Topical Score = 100
#     - Candidate 'Stefan F. Preble' | Topical Score = 20
#     - Candidate 'Stefan F. Preble' | Topical Score = 0
#     - Candidate 'Stefan F. Preble' | Topical Score = 30
#   -> Best Match Selected: 'S. Preble' with a score of 124.10
#   -> Fetching full details for S2 ID: 2677531...
#   -> SUCCESS: Saved detailed data to s2_author_data/000061012.json
#
# [50/50] Processing: Anna K Hull (NSF ID: 000061204)
#   -> Matching against NSF Keywords: {'leaps', 'scholars'}
#     - Candidate 'A. K. Hull' | Topical Score = 0
#     - Candidate 'Anna K. Hull' | Topical Score = 0
#     - Candidate 'Anna K Hull' | Topical Score = 0
#   -> Best Match Selected: 'A. K. Hull' with a score of 0.80
#   -> Fetching full details for S2 ID: 37526830...
#   -> SUCCESS: Saved detailed data to s2_author_data/000061204.json
#
# --- Full Enrichment Pipeline Complete ---
