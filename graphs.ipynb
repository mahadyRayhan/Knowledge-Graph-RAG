# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Data
# top_k = [1, 3, 5, 10]
# precision = [0.737, 0.737, 0.737, 0.751]
# recall = [0.737, 0.737, 0.737, 0.747]
# f1 = [0.737, 0.737, 0.737, 0.749]
# rate = [0.737, 0.526, 0.463, 0.305]

# # Bar width and positions
# bar_width = 0.2
# x = np.arange(len(top_k))

# plt.figure(figsize=(9, 6))

# # Hatch patterns
# hatch_patterns = ['////', '.....', 'xxx', '\\\\\\\\']

# # Plot bars
# bars1 = plt.bar(x - 1.5 * bar_width, precision, width=bar_width, label='Precision', color='white', edgecolor='black', hatch=hatch_patterns[0])
# bars2 = plt.bar(x - 0.5 * bar_width, recall, width=bar_width, label='Recall', color='white', edgecolor='black', hatch=hatch_patterns[1])
# bars3 = plt.bar(x + 0.5 * bar_width, f1, width=bar_width, label='F1', color='white', edgecolor='black', hatch=hatch_patterns[2])
# bars4 = plt.bar(x + 1.5 * bar_width, rate, width=bar_width, label='Rate', color='white', edgecolor='black', hatch=hatch_patterns[3])

# # Adding value labels on top of each bar
# def add_labels(bars):
#     for bar in bars:
#         height = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width()/2, height + 0.02, f'{height:.3f}', 
#                  ha='center', va='bottom', fontsize=15, fontweight='bold', rotation=45)

# add_labels(bars1)
# add_labels(bars2)
# add_labels(bars3)
# add_labels(bars4)

# # Labels and legend
# plt.xlabel('TOP K', fontsize=20, fontweight='bold')
# plt.ylabel('Score', fontsize=20, fontweight='bold')
# plt.xticks(ticks=x, labels=top_k, fontsize=12, fontweight='bold')
# plt.yticks(fontsize=20, fontweight='bold')
# plt.legend(fontsize=20, frameon=True)
# plt.title('Multi-Bar Graph for Performance Metrics', fontsize=16, fontweight='bold')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.ylim(0, max(precision + recall + f1 + rate) + 0.1)  # Ensure values are not cut off
# plt.tight_layout()
# plt.subplots_adjust(top=1.2)

# # Show plot
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Data
# top_k = ['Movie Gemini', 'Movie Gpt', 'Scholar Gemini', 'Scholar Gpt']

# precision_k1 = [0.737, 0.579, 0.842, 0.579]
# precision_k3 = [0.737, 0.614, 0.842, 0.526]
# precision_k5 = [0.737, 0.642, 0.842, 0.558]
# precision_k10 = [0.751, 0.7, 0.842, 0.557]

# # Bar width and positions
# bar_width = 0.2
# x = np.arange(len(top_k))
# plt.rcParams['font.family'] = 'Times New Roman'


# plt.figure(figsize=(10, 6))  # Expanded x-axis width

# # Hatch patterns
# hatch_patterns = ['////', '.....', 'xxx', '\\\\\\\\']

# # Plot bars
# bars1 = plt.bar(x - 1.5 * bar_width, precision_k1, width=bar_width, label='K=1', color='white', edgecolor='black', hatch=hatch_patterns[0])
# bars2 = plt.bar(x - 0.5 * bar_width, precision_k3, width=bar_width, label='K=2', color='white', edgecolor='black', hatch=hatch_patterns[1])
# bars3 = plt.bar(x + 0.5 * bar_width, precision_k5, width=bar_width, label='K=3', color='white', edgecolor='black', hatch=hatch_patterns[2])
# bars4 = plt.bar(x + 1.5 * bar_width, precision_k10, width=bar_width, label='K=4', color='white', edgecolor='black', hatch=hatch_patterns[3])

# # Adding value labels on top of each bar
# def add_labels(bars):
#     for bar in bars:
#         height = bar.get_height()
#         plt.text(bar.get_x() + bar.get_width()/2, height + 0.005, f'{height:.3f}', 
#                  ha='center', va='bottom', fontsize=15, fontweight='bold', rotation=45)

# add_labels(bars1)
# add_labels(bars2)
# add_labels(bars3)
# add_labels(bars4)

# # Labels and legend
# plt.xlabel('Dataset - Model', fontsize=20, fontweight='bold')
# plt.ylabel('Precision', fontsize=20, fontweight='bold')
# plt.xticks(ticks=x, labels=top_k, fontsize=15, fontweight='bold')
# plt.yticks(fontsize=15, fontweight='bold')
# plt.legend(fontsize=15, frameon=True)
# plt.title('Gemini Performance Metrics on Movie Dataset', fontsize=16, fontweight='bold')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.ylim(0, max(precision + recall + f1 + rate) + 0.2)  # Extend y-axis to fit legend inside the plot

# save_path = 'graphs/Gemini_Performance_Metrics_Movie_Dataset.png'
# plt.savefig(save_path, dpi=300, bbox_inches='tight')
# # Show plot
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
data_llm = ['1', '3', '5', '10']

M_G = [0.737, 0.737, 0.737, 0.751]
M_P = [0.579, 0.614, 0.642, 0.7]
S_G = [0.842, 0.842, 0.842, 0.842]
S_P = [0.579, 0.526, 0.558, 0.557]

# Bar width and positions
bar_width = 0.2
x = np.arange(len(data_llm))
plt.rcParams['font.family'] = 'Times New Roman'


plt.figure(figsize=(10, 6))  # Expanded x-axis width

# Hatch patterns
hatch_patterns = ['////', '.....', 'xxx', '\\\\\\\\']

# Plot bars
bars1 = plt.bar(x - 1.5 * bar_width, M_G, width=bar_width, label='Movie-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[0])
bars2 = plt.bar(x - 0.5 * bar_width, M_P, width=bar_width, label='Movie-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[1])
bars3 = plt.bar(x + 0.5 * bar_width, S_G, width=bar_width, label='Scholar-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[2])
bars4 = plt.bar(x + 1.5 * bar_width, S_P, width=bar_width, label='Scholar-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[3])

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height + 0.005, f'{height:.3f}', 
                 ha='center', va='bottom', fontsize=15, fontweight='bold', rotation=45)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)
add_labels(bars4)

# Labels and legend
plt.xlabel('Top K', fontsize=20, fontweight='bold')
plt.ylabel('Precision', fontsize=20, fontweight='bold')
plt.xticks(ticks=x, labels=data_llm, fontsize=15, fontweight='bold')
plt.yticks(fontsize=15, fontweight='bold')
plt.legend(fontsize=15, frameon=True)
# plt.title('Precision on Different Dataset & LLM', fontsize=16, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(0, 0.8 + 0.2)  # Extend y-axis to fit legend inside the plot

save_path = 'graphs/Precision-Different-Dataset-LLM.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
data_llm = ['1', '3', '5', '10']

M_G = [0.737, 0.737, 0.737, 0.747]
M_P = [0.578947368, 0.614035088, 0.621052632, 0.679699248]
S_G = [0.842105263, 0.842105263, 0.842105263, 0.842105263]
S_P = [0.578947368, 0.526315789, 0.557894737, 0.547368421]

# Bar width and positions
bar_width = 0.2
x = np.arange(len(data_llm))
plt.rcParams['font.family'] = 'Times New Roman'


plt.figure(figsize=(10, 6))  # Expanded x-axis width

# Hatch patterns
hatch_patterns = ['////', '.....', 'xxx', '\\\\\\\\']

# Plot bars
bars1 = plt.bar(x - 1.5 * bar_width, M_G, width=bar_width, label='Movie-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[0])
bars2 = plt.bar(x - 0.5 * bar_width, M_P, width=bar_width, label='Movie-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[1])
bars3 = plt.bar(x + 0.5 * bar_width, S_G, width=bar_width, label='Scholar-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[2])
bars4 = plt.bar(x + 1.5 * bar_width, S_P, width=bar_width, label='Scholar-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[3])

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height + 0.005, f'{height:.3f}', 
                 ha='center', va='bottom', fontsize=15, fontweight='bold', rotation=45)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)
add_labels(bars4)

# Labels and legend
plt.xlabel('Top K', fontsize=20, fontweight='bold')
plt.ylabel('Recall', fontsize=20, fontweight='bold')
plt.xticks(ticks=x, labels=data_llm, fontsize=15, fontweight='bold')
plt.yticks(fontsize=15, fontweight='bold')
plt.legend(fontsize=15, frameon=True)
# plt.title('Recall on Different Dataset & LLM', fontsize=16, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(0, 0.8 + 0.2)  # Extend y-axis to fit legend inside the plot

save_path = 'graphs/Recall-Different-Dataset-LLM.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
data_llm = ['1', '3', '5', '10']

M_G = [0.737, 0.737, 0.737, 0.749]
M_P = [0.578947368, 0.614035088, 0.628947368, 0.680701754]
S_G = [0.842105263, 0.842105263, 0.842105263, 0.842105263]
S_P = [0.578947368, 0.526315789, 0.557894737, 0.543734336]

# Bar width and positions
bar_width = 0.2
x = np.arange(len(data_llm))
plt.rcParams['font.family'] = 'Times New Roman'


plt.figure(figsize=(10, 6))  # Expanded x-axis width

# Hatch patterns
hatch_patterns = ['////', '.....', 'xxx', '\\\\\\\\']

# Plot bars
bars1 = plt.bar(x - 1.5 * bar_width, M_G, width=bar_width, label='Movie-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[0])
bars2 = plt.bar(x - 0.5 * bar_width, M_P, width=bar_width, label='Movie-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[1])
bars3 = plt.bar(x + 0.5 * bar_width, S_G, width=bar_width, label='Scholar-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[2])
bars4 = plt.bar(x + 1.5 * bar_width, S_P, width=bar_width, label='Scholar-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[3])

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height + 0.005, f'{height:.3f}', 
                 ha='center', va='bottom', fontsize=15, fontweight='bold', rotation=45)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)
add_labels(bars4)

# Labels and legend
plt.xlabel('Top K', fontsize=20, fontweight='bold')
plt.ylabel('F1', fontsize=20, fontweight='bold')
plt.xticks(ticks=x, labels=data_llm, fontsize=15, fontweight='bold')
plt.yticks(fontsize=15, fontweight='bold')
plt.legend(fontsize=15, frameon=True)
# plt.title('F1 on Different Dataset & LLM', fontsize=16, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(0, 0.8 + 0.2)  # Extend y-axis to fit legend inside the plot

save_path = 'graphs/F1-Different-Dataset-LLM.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
data_llm = ['1', '3', '5', '10']

M_G = [0.737, 0.526, 0.463, 0.305]
M_P = [0.578947368, 0.385964912, 0.294736842, 0.236842105]
S_G = [0.842105263, 0.578947368, 0.515789474, 0.405263158]
S_P = [0.578947368, 0.385964912, 0.368421053, 0.257894737]

# Bar width and positions
bar_width = 0.2
x = np.arange(len(data_llm))
plt.rcParams['font.family'] = 'Times New Roman'


plt.figure(figsize=(10, 6))  # Expanded x-axis width

# Hatch patterns
hatch_patterns = ['////', '.....', 'xxx', '\\\\\\\\']

# Plot bars
bars1 = plt.bar(x - 1.5 * bar_width, M_G, width=bar_width, label='Movie-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[0])
bars2 = plt.bar(x - 0.5 * bar_width, M_P, width=bar_width, label='Movie-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[1])
bars3 = plt.bar(x + 0.5 * bar_width, S_G, width=bar_width, label='Scholar-Gemini', color='white', edgecolor='black', hatch=hatch_patterns[2])
bars4 = plt.bar(x + 1.5 * bar_width, S_P, width=bar_width, label='Scholar-Gpt', color='white', edgecolor='black', hatch=hatch_patterns[3])

# Adding value labels on top of each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height + 0.005, f'{height:.3f}', 
                 ha='center', va='bottom', fontsize=15, fontweight='bold', rotation=45)

add_labels(bars1)
add_labels(bars2)
add_labels(bars3)
add_labels(bars4)

# Labels and legend
plt.xlabel('Top K', fontsize=20, fontweight='bold')
plt.ylabel('Rate', fontsize=20, fontweight='bold')
plt.xticks(ticks=x, labels=data_llm, fontsize=15, fontweight='bold')
plt.yticks(fontsize=15, fontweight='bold')
plt.legend(fontsize=15, frameon=True)
# plt.title('Rate on Different Dataset & LLM', fontsize=16, fontweight='bold')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(0, 0.8 + 0.2)  # Extend y-axis to fit legend inside the plot

save_path = 'graphs/Rate-Different-Dataset-LLM.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Times New Roman'


# Data
metrics = ["ROUGE-1", "ROUGE-2", "ROUGE-L", "BLEU", "Cosine Similarity"]

movie_gemini = [0.646975066, 0.519968115, 0.625905679, 0.343702231, 0.748219902]
movie_gpt = [0.607131079, 0.380223279, 0.498709668, 0.251305058, 0.771268286]
scholar_gemini = [0.800846893, 0.769813038, 0.76970308, 0.721665698, 0.833788009]
scholar_gpt = [0.645634205, 0.528996084, 0.553731964, 0.387898562, 0.703625095]

x = np.arange(len(metrics))  # X-axis positions

plt.figure(figsize=(10, 6))
plt.plot(x, movie_gemini, marker='o', linestyle='-', label='Movie-Gemini')
plt.plot(x, movie_gpt, marker='s', linestyle='--', label='Movie-GPT')
plt.plot(x, scholar_gemini, marker='^', linestyle='-', label='Scholar-Gemini')
plt.plot(x, scholar_gpt, marker='d', linestyle='--', label='Scholar-GPT')

# Labels and Title
plt.xticks(ticks=x, labels=metrics, fontsize=15, fontweight='bold')
plt.xlabel('LLM Metrics', fontsize=20, fontweight='bold')
plt.ylabel('Score', fontsize=20, fontweight='bold')
plt.yticks([0.0, 0.2, 0.4, 0.6, 0.8],fontsize=20, fontweight='bold')
plt.xticks(x, metrics, rotation=25)
# plt.title("Comparison of Model Performance{LLM)}", fontsize=16, fontweight='bold')
plt.legend(fontsize=15, frameon=True, loc = 'lower left')
plt.grid(linestyle='--', alpha=0.7)
plt.ylim(0, 0.8 + 0.1)  # Extend y-axis to fit legend inside the plot

save_path = 'graphs/LLM-performence.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
# Show Plot
plt.show()
